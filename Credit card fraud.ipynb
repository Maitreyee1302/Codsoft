# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
credit_card = pd.read_csv("C:/Users/Maitreyee/Downloads/archive (2)/creditcard.csv")
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card.shape
# Out:
# (284807, 31)

# %%
credit_card.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
nonfraud = len(credit_card[credit_card.Class == 0])

# %%
fraud = len(credit_card[credit_card.Class == 1])

# %%
f_percent = (fraud/(fraud+nonfraud))*100

# %%
print(f_percent)
# Out:
# 0.1727485630620034

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
credit_card['normalized_amount'] = scaler.fit_transform(credit_card['Amount'].values.reshape(-1, 1))

# %%
credit_card.drop(['Amount', 'Time'], inplace=True, axis=1)

# %%
credit_card.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Class  normalized_amount
# ...

# %%
x = credit_card.drop(['Class'], axis=1)

# %%
y = credit_card['Class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 1)

# %%
print(x_train)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 191125 -0.190075  0.203323 -0.996232 -1.596985  3.192579  3.356935  0.288299
# 153710 -0.000313  1.041633 -0.318849 -0.429824  0.927591 -0.784796  0.815404
# 261216  2.065603  0.071537 -1.892041  0.190985  0.681571 -0.286226  0.051364
# 190724  2.025587  0.060125 -1.843486  0.347168  0.301427 -0.955263  0.073910
# 127492 -0.482824  0.692865  1.397751  0.822699 -0.815530  0.143287 -0.419970
# ...          ...       ...       ...       ...       ...       ...       ...
# 21440  -2.986845 -8.663978 -1.910863  0.664058 -3.934875  0.861269  1.647511
# 117583  0.937083 -0.849673  0.524186 -0.020031 -0.606327  0.692302 -0.463724
# 73349  -1.149963  1.696462  1.637114  2.658991 -0.021502  0.192287  0.205204
# 267336  1.754554 -0.699398 -0.076332  0.443915 -0.672082  0.389061 -0.807534
# 128037 -0.707635  0.493302  2.648089  1.064807 -0.680271  1.183838  0.169413
#
# ...

# %%
print(x_test)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 169876 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887  0.292491
# 127467 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985  0.321552
# 137900 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484  0.706252
# 21513  -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733  0.681867
# 134700  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002  0.373692
# ...          ...       ...       ...       ...       ...       ...       ...
# 128956  1.270567  0.120127 -0.325654  0.862062 -0.035647 -0.257454 -0.198930
# 177494  2.006508 -0.398689 -2.952190 -1.055997  2.542666  2.992624 -0.184526
# 26287  -0.176040  1.093239  2.165256  2.034383  0.459114  0.543965  0.525887
# 198160  2.000943 -0.480504 -0.665745  0.230648 -0.166581  0.337040 -0.649903
# 25893   1.061664 -0.307508  0.582271  0.678654 -0.762735 -0.358402 -0.329295
#
# ...

# %%
print(y_train)
# Out:
# 191125    0
# 153710    0
# 261216    0
# 190724    0
# 127492    0
#          ..
# 21440     0
# 117583    0
# 73349     0
# 267336    0
# 128037    0
# Name: Class, Length: 199364, dtype: int64

# %%
print(y_test)
# Out:
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
#          ..
# 128956    0
# 177494    0
# 26287     0
# 198160    0
# 25893     0
# Name: Class, Length: 85443, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest = RandomForestClassifier(n_estimators=100)

# %%
random_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
prediction = random_forest.predict(x_test)

# %%
rf_score = random_forest.score(x_test, y_test)*100

# %%
print(rf_score)
# Out:
# 99.94967405170698
